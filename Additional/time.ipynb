# %%
#!for a in /sys/bus/pci/devices/*; do echo 0 | sudo tee -a $a/numa_node; done
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from data_processing import dataset
from models import model
from utils import tools
from plots import plots, edge_detection_plots

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
#np.set_printoptions(threshold=sys.maxsize)
# Out:
# 2022-12-15 19:18:13.110567: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-15 19:18:13.196919: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-15 19:18:13.217658: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-15 19:18:13.621229: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ros/noetic/lib:/home/david/miniconda3/envs/tf/lib/
# 2022-12-15 19:18:13.621284: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ros/noetic/lib:/home/david/miniconda3/envs/tf/lib/
# 2022-12-15 19:18:13.621288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
config_directory = 'time'

config_path = os.path.join(os.getcwd(), 'configs', config_directory)
Model = model.Model(config_path)
DataProcessing = dataset.DataProcessing(input_shape_img=Model.cfg["INPUT_SHAPE_IMG"],
                                        input_shape_mask=Model.cfg["INPUT_SHAPE_MASK"],
                                        output_shape=Model.cfg["OUTPUT_SHAPE"],
                                        config_path=config_path)
tools.parser(Model.cfg, DataProcessing.cfg)
Model.load_data(DataProcessing.cfg["NAME"])
DataProcessing.path_definitions()
# Out:
# 2022-12-15 19:18:14.743635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:14.746922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:14.747015: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:14.747346: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-15 19:18:14.747644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:14.747736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:14.747800: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:15.154046: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:15.154167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:15.154239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 19:18:15.154291: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-12-15 19:18:15.154311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9719 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:22:00.0, compute capability: 8.6

# %% [markdown]
# # Load Dataset, Preprocess Images and Dataset

# %%
if Model.train_model:
    train_ds, img_count_train = DataProcessing.load_dataset(DataProcessing.key.train)
test_ds, img_count_test = DataProcessing.load_dataset(DataProcessing.key.test)

if Model.train_model:
    for inp, out in train_ds.take(1):
        edge_detection_plots.plot_edges(images=inp['in_img'], labels=out['out_edge'],
                                        batch_size=DataProcessing.cfg['TEST']['BATCH_SIZE'],
                                        num_classes=DataProcessing.num_classes['edge'])
# Out:
# The TRAIN DS contains 500 images.
# The TEST DS contains 100 images.

# %% [markdown]
# # Define, Compile and Train Model

# %%
if Model.train_model:
    model = Model.get_neural_network_model(DataProcessing.num_classes['edge'])
    # model.summary()

    lr = Model.get_lr(img_count_train, DataProcessing.cfg['TRAIN']['BATCH_SIZE'])
    model.compile(optimizer=tf.keras.optimizers.Adam(lr),
                  loss=Model.get_loss_function(),
                  metrics=Model.get_metrics(DataProcessing.num_classes['edge']))

    history = model.fit(train_ds, epochs=Model.cfg["EPOCHS"], validation_data=train_ds,
                        callbacks=Model.get_callbacks(), verbose=1)

model = Model.get_best_model_from_checkpoints()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/10
# 2022-12-15 19:18:26.094881: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-12-15 19:18:26.538965: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 499/499 [==============================] - 24s 29ms/step - loss: 1069.9941 - accuracy: 0.7686 - accuracy_1: 0.7686 - f1: 0.1025 - precision: 0.0793 - recall: 0.1768 - f1_1: 0.1025 - precision_1: 0.0793 - recall_1: 0.1768 - val_loss: 716.4337 - val_accuracy: 0.9192 - val_accuracy_1: 0.9192 - val_f1: 0.0097 - val_precision: 0.9075 - val_recall: 0.0049 - val_f1_1: 0.0097 - val_precision_1: 0.9075 - val_recall_1: 0.0049
# Epoch 2/10
# 499/499 [==============================] - 13s 27ms/step - loss: 552.6871 - accuracy: 0.9166 - accuracy_1: 0.9166 - f1: 0.0094 - precision: 0.6350 - recall: 0.0047 - f1_1: 0.0094 - precision_1: 0.6350 - recall_1: 0.0047 - val_loss: 548.8600 - val_accuracy: 0.9198 - val_accuracy_1: 0.9198 - val_f1: 0.0259 - val_precision: 0.8806 - val_recall: 0.0131 - val_f1_1: 0.0259 - val_precision_1: 0.8806 - val_recall_1: 0.0131
# Epoch 9/10
# 499/499 [==============================] - 13s 27ms/step - loss: 552.2841 - accuracy: 0.9213 - accuracy_1: 0.9213 - f1: 0.0100 - precision: 0.6005 - recall: 0.0050 - f1_1: 0.0100 - precision_1: 0.6005 - recall_1: 0.0050 - val_loss: 547.4249 - val_accuracy: 0.9200 - val_accuracy_1: 0.9200 - val_f1: 0.0326 - val_precision: 0.8734 - val_recall: 0.0166 - val_f1_1: 0.0326 - val_precision_1: 0.8734 - val_recall_1: 0.0166
# Epoch 10/10
# 499/499 [==============================] - ETA: 0s - loss: 551.7191 - accuracy: 0.9193 - accuracy_1: 0.9193 - f1: 0.0134 - precision: 0.6186 - recall: 0.0068 - f1_1: 0.0134 - precision_1: 0.6186 - recall_1: 0.0068
# Epoch 10: saving model to /home/david/SemesterProject/Models/edge_detection/time/CKPT/ckpt-loss=547.20-epoch=10.00-f1=0.0303
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 121). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/edge_detection/time/CKPT/ckpt-loss=547.20-epoch=10.00-f1=0.0303/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/edge_detection/time/CKPT/ckpt-loss=547.20-epoch=10.00-f1=0.0303/assets
# 499/499 [==============================] - 34s 68ms/step - loss: 551.7191 - accuracy: 0.9193 - accuracy_1: 0.9193 - f1: 0.0134 - precision: 0.6186 - recall: 0.0068 - f1_1: 0.0134 - precision_1: 0.6186 - recall_1: 0.0068 - val_loss: 547.1989 - val_accuracy: 0.9199 - val_accuracy_1: 0.9199 - val_f1: 0.0303 - val_precision: 0.8607 - val_recall: 0.0154 - val_f1_1: 0.0303 - val_precision_1: 0.8607 - val_recall_1: 0.0154
# /home/david/SemesterProject/Models/edge_detection/time/CKPT/ckpt-loss=547.20-epoch=10.00-f1=0.0303
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 121). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/edge_detection/time/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/edge_detection/time/assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 121). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/edge_detection/time/TFLITE/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/edge_detection/time/TFLITE/assets

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  in_img (InputLayer)            [(None, 160, 90, 3)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 160, 90, 10)  280         ['in_img[0][0]']
#
#  batch_normalization (BatchNorm  (None, 160, 90, 10)  40         ['conv2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 160, 90, 10)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 160, 90, 2)   22          ['re_lu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 160, 90, 2)   22          ['re_lu[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 160, 90, 2)   22          ['re_lu[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 160, 90, 2)   22          ['re_lu[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 160, 90, 2)   22          ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 160, 90, 2)  8           ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 160, 90, 2)  8           ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 160, 90, 2)  8           ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 160, 90, 2)  8           ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 160, 90, 2)  8           ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_2[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_3[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_4[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_5[0][0]']
#
#  add (Add)                      (None, 160, 90, 2)   0           ['re_lu_1[0][0]',
#                                                                   're_lu_2[0][0]',
#                                                                   're_lu_3[0][0]',
#                                                                   're_lu_4[0][0]',
#                                                                   're_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 160, 90, 1)   3           ['add[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 160, 90, 1)  4           ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 160, 90, 2)   4           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 160, 90, 2)   4           ['batch_normalization_6[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 160, 90, 2)   4           ['batch_normalization_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_6[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 160, 90, 2)  8           ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 160, 90, 2)  8           ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 160, 90, 2)  8           ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 160, 90, 2)  8           ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 160, 90, 2)  8           ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_6 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_7[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_8[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_9[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 160, 90, 2)   0           ['batch_normalization_10[0][0]']
#
#  re_lu_10 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_11[0][0]']
#
#  add_1 (Add)                    (None, 160, 90, 2)   0           ['re_lu_6[0][0]',
#                                                                   're_lu_7[0][0]',
#                                                                   're_lu_8[0][0]',
#                                                                   're_lu_9[0][0]',
#                                                                   're_lu_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 160, 90, 1)   3           ['add_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 160, 90, 1)  4           ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_12[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 160, 90, 2)  8           ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 160, 90, 2)  8           ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 160, 90, 2)  8           ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 160, 90, 2)  8           ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 160, 90, 2)  8           ['conv2d_17[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_13[0][0]']
#
#  re_lu_12 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_14[0][0]']
#
#  re_lu_13 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_15[0][0]']
#
#  re_lu_14 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_16[0][0]']
#
#  re_lu_15 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_17[0][0]']
#
#  add_2 (Add)                    (None, 160, 90, 2)   0           ['re_lu_11[0][0]',
#                                                                   're_lu_12[0][0]',
#                                                                   're_lu_13[0][0]',
#                                                                   're_lu_14[0][0]',
#                                                                   're_lu_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 160, 90, 1)   3           ['add_2[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 160, 90, 1)  4           ['conv2d_18[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_18[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 160, 90, 2)  8           ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 160, 90, 2)  8           ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 160, 90, 2)  8           ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 160, 90, 2)  8           ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 160, 90, 2)  8           ['conv2d_23[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_19[0][0]']
#
#  re_lu_17 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_20[0][0]']
#
#  re_lu_18 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_21[0][0]']
#
#  re_lu_19 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_22[0][0]']
#
#  re_lu_20 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_23[0][0]']
#
#  add_3 (Add)                    (None, 160, 90, 2)   0           ['re_lu_16[0][0]',
#                                                                   're_lu_17[0][0]',
#                                                                   're_lu_18[0][0]',
#                                                                   're_lu_19[0][0]',
#                                                                   're_lu_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 160, 90, 1)   3           ['add_3[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 160, 90, 1)  4           ['conv2d_24[0][0]']
#  ormalization)
#
#  conv2d_25 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_24[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_24[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_24[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 160, 90, 2)  8           ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 160, 90, 2)  8           ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 160, 90, 2)  8           ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 160, 90, 2)  8           ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 160, 90, 2)  8           ['conv2d_29[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_25[0][0]']
#
#  re_lu_22 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_26[0][0]']
#
#  re_lu_23 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_27[0][0]']
#
#  re_lu_24 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_28[0][0]']
#
#  re_lu_25 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_29[0][0]']
#
#  add_4 (Add)                    (None, 160, 90, 2)   0           ['re_lu_21[0][0]',
#                                                                   're_lu_22[0][0]',
#                                                                   're_lu_23[0][0]',
#                                                                   're_lu_24[0][0]',
#                                                                   're_lu_25[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 160, 90, 1)   3           ['add_4[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 160, 90, 1)  4           ['conv2d_30[0][0]']
#  ormalization)
#
#  conv2d_31 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_30[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_30[0][0]']
#  conv2d_34 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_30[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 160, 90, 2)  8           ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 160, 90, 2)  8           ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 160, 90, 2)  8           ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 160, 90, 2)  8           ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 160, 90, 2)  8           ['conv2d_35[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_31[0][0]']
#
#  re_lu_27 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_32[0][0]']
#
#  re_lu_28 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_33[0][0]']
#
#  re_lu_29 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_34[0][0]']
#
#  re_lu_30 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_35[0][0]']
#
#  add_5 (Add)                    (None, 160, 90, 2)   0           ['re_lu_26[0][0]',
#                                                                   're_lu_27[0][0]',
#                                                                   're_lu_28[0][0]',
#                                                                   're_lu_29[0][0]',
#                                                                   're_lu_30[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 160, 90, 1)   3           ['add_5[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 160, 90, 1)  4           ['conv2d_36[0][0]']
#  ormalization)
#
#  conv2d_37 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_36[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_36[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 160, 90, 2)  8           ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 160, 90, 2)  8           ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 160, 90, 2)  8           ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 160, 90, 2)  8           ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 160, 90, 2)  8           ['conv2d_41[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_37[0][0]']
#
#  re_lu_32 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_38[0][0]']
#
#  re_lu_33 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_39[0][0]']
#
#  re_lu_34 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_40[0][0]']
#
#  re_lu_35 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_41[0][0]']
#
#  add_6 (Add)                    (None, 160, 90, 2)   0           ['re_lu_31[0][0]',
#                                                                   're_lu_32[0][0]',
#                                                                   're_lu_33[0][0]',
#                                                                   're_lu_34[0][0]',
#                                                                   're_lu_35[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 160, 90, 1)   3           ['add_6[0][0]']
#  batch_normalization_42 (BatchN  (None, 160, 90, 1)  4           ['conv2d_42[0][0]']
#  ormalization)
#
#  conv2d_43 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_42[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_42[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_42[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 160, 90, 2)  8           ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 160, 90, 2)  8           ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 160, 90, 2)  8           ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 160, 90, 2)  8           ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 160, 90, 2)  8           ['conv2d_47[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_43[0][0]']
#
#  re_lu_37 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_44[0][0]']
#
#  re_lu_38 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_45[0][0]']
#
#  re_lu_39 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_46[0][0]']
#
#  re_lu_40 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_47[0][0]']
#
#  add_7 (Add)                    (None, 160, 90, 2)   0           ['re_lu_36[0][0]',
#                                                                   're_lu_37[0][0]',
#                                                                   're_lu_38[0][0]',
#                                                                   're_lu_39[0][0]',
#                                                                   're_lu_40[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 160, 90, 1)   3           ['add_7[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 160, 90, 1)  4           ['conv2d_48[0][0]']
#  ormalization)
#
#  conv2d_49 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_48[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_48[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 160, 90, 2)  8           ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 160, 90, 2)  8           ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 160, 90, 2)  8           ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 160, 90, 2)  8           ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 160, 90, 2)  8           ['conv2d_53[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_49[0][0]']
#
#  re_lu_42 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_50[0][0]']
#
#  re_lu_43 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_51[0][0]']
#
#  re_lu_44 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_52[0][0]']
#
#  re_lu_45 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_53[0][0]']
#
#  add_8 (Add)                    (None, 160, 90, 2)   0           ['re_lu_41[0][0]',
#                                                                   're_lu_42[0][0]',
#                                                                   're_lu_43[0][0]',
#                                                                   're_lu_44[0][0]',
#                                                                   're_lu_45[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 160, 90, 1)   3           ['add_8[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 160, 90, 1)  4           ['conv2d_54[0][0]']
#  ormalization)
#
#  conv2d_55 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_54[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_54[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 160, 90, 2)  8           ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 160, 90, 2)  8           ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 160, 90, 2)  8           ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 160, 90, 2)  8           ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 160, 90, 2)  8           ['conv2d_59[0][0]']
#  ormalization)
#
#  re_lu_46 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_55[0][0]']
#
#  re_lu_47 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_56[0][0]']
#
#  re_lu_48 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_57[0][0]']
#
#  re_lu_49 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_58[0][0]']
#
#  re_lu_50 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_59[0][0]']
#
#  add_9 (Add)                    (None, 160, 90, 2)   0           ['re_lu_46[0][0]',
#                                                                   're_lu_47[0][0]',
#                                                                   're_lu_48[0][0]',
#                                                                   're_lu_49[0][0]',
#                                                                   're_lu_50[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 160, 90, 1)   3           ['add_9[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 160, 90, 1)  4           ['conv2d_60[0][0]']
#  ormalization)
#
#  conv2d_61 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_60[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_60[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_60[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_60[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 160, 90, 2)   4           ['batch_normalization_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 160, 90, 2)  8           ['conv2d_61[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 160, 90, 2)  8           ['conv2d_62[0][0]']
#  ormalization)
# ...
#  re_lu_82 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_98[0][0]']
#
#  re_lu_83 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_99[0][0]']
#
#  re_lu_84 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_100[0][0]']
#
#  re_lu_85 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_101[0][0]']
#
#  add_16 (Add)                   (None, 160, 90, 2)   0           ['re_lu_81[0][0]',
#                                                                   're_lu_82[0][0]',
#                                                                   're_lu_83[0][0]',
#                                                                   're_lu_84[0][0]',
#                                                                   're_lu_85[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 160, 90, 1)   3           ['add_16[0][0]']
#
#  batch_normalization_102 (Batch  (None, 160, 90, 1)  4           ['conv2d_102[0][0]']
#  Normalization)
#
#  conv2d_103 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_102[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_102[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_102[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_102[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_102[0][0]']
#
#  batch_normalization_103 (Batch  (None, 160, 90, 2)  8           ['conv2d_103[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 160, 90, 2)  8           ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 160, 90, 2)  8           ['conv2d_105[0][0]']
#  Normalization)
#
#  batch_normalization_106 (Batch  (None, 160, 90, 2)  8           ['conv2d_106[0][0]']
#  Normalization)
#
#  batch_normalization_107 (Batch  (None, 160, 90, 2)  8           ['conv2d_107[0][0]']
#  Normalization)
#
#  re_lu_86 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_103[0][0]']
#
#  re_lu_87 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_104[0][0]']
#
#  re_lu_88 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_105[0][0]']
#
#  re_lu_89 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_106[0][0]']
#
#  re_lu_90 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_107[0][0]']
#  add_17 (Add)                   (None, 160, 90, 2)   0           ['re_lu_86[0][0]',
#                                                                   're_lu_87[0][0]',
#                                                                   're_lu_88[0][0]',
#                                                                   're_lu_89[0][0]',
#                                                                   're_lu_90[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 160, 90, 1)   3           ['add_17[0][0]']
#
#  batch_normalization_108 (Batch  (None, 160, 90, 1)  4           ['conv2d_108[0][0]']
#  Normalization)
#
#  conv2d_109 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_108[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_108[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_108[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_108[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_108[0][0]']
#
#  batch_normalization_109 (Batch  (None, 160, 90, 2)  8           ['conv2d_109[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 160, 90, 2)  8           ['conv2d_110[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 160, 90, 2)  8           ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 160, 90, 2)  8           ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_113 (Batch  (None, 160, 90, 2)  8           ['conv2d_113[0][0]']
#  Normalization)
#
#  re_lu_91 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_109[0][0]']
#
#  re_lu_92 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_110[0][0]']
#
#  re_lu_93 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_111[0][0]']
#
#  re_lu_94 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_112[0][0]']
#
#  re_lu_95 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_113[0][0]']
#
#  add_18 (Add)                   (None, 160, 90, 2)   0           ['re_lu_91[0][0]',
#                                                                   're_lu_92[0][0]',
#                                                                   're_lu_93[0][0]',
#                                                                   're_lu_94[0][0]',
#                                                                   're_lu_95[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 160, 90, 1)   3           ['add_18[0][0]']
#
#  batch_normalization_114 (Batch  (None, 160, 90, 1)  4           ['conv2d_114[0][0]']
#  Normalization)
#
#  conv2d_115 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_114[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_114[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_114[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_114[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 160, 90, 2)   4           ['batch_normalization_114[0][0]']
#
#  batch_normalization_115 (Batch  (None, 160, 90, 2)  8           ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 160, 90, 2)  8           ['conv2d_116[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 160, 90, 2)  8           ['conv2d_117[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 160, 90, 2)  8           ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 160, 90, 2)  8           ['conv2d_119[0][0]']
#  Normalization)
#
#  re_lu_96 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_115[0][0]']
#
#  re_lu_97 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_116[0][0]']
#
#  re_lu_98 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_117[0][0]']
#
#  re_lu_99 (ReLU)                (None, 160, 90, 2)   0           ['batch_normalization_118[0][0]']
#
#  re_lu_100 (ReLU)               (None, 160, 90, 2)   0           ['batch_normalization_119[0][0]']
#
#  add_19 (Add)                   (None, 160, 90, 2)   0           ['re_lu_96[0][0]',
#                                                                   're_lu_97[0][0]',
#                                                                   're_lu_98[0][0]',
#                                                                   're_lu_99[0][0]',
#                                                                   're_lu_100[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 160, 90, 1)   3           ['add_19[0][0]']
#
#  batch_normalization_120 (Batch  (None, 160, 90, 1)  4           ['conv2d_120[0][0]']
#  Normalization)
#
#  out_edge (Activation)          (None, 160, 90, 1)   0           ['batch_normalization_120[0][0]']
#
# ==================================================================================================
# Total params: 1,750
# Trainable params: 0
# Non-trainable params: 1,750
# __________________________________________________________________________________________________

# %% [markdown]
# # Plot Results

# %%
if Model.train_model:
    plot_losses = ["loss", "loss"]
    plot_metrics = ["accuracy", "f1", "recall", "precision"]

    path = os.path.join(Model.Data.paths["FIGURES"], "training.svg")

    plots.plot_training_history(history=history.history, list_of_loss_names=plot_losses,
                                list_of_metric_names=plot_metrics,
                                save=Model.cfg["SAVE"], path=path)

# %%
for inp, out in test_ds.take(1):
    pred = model.predict(inp)
    edge_detection_plots.plot_edges(images=inp['in_img'],
                                    labels=out['out_edge'],
                                    predictions=pred,
                                    batch_size=DataProcessing.cfg['TEST']['BATCH_SIZE'],
                                    num_classes=DataProcessing.num_classes['edge'])
# Out:
# 1/1 [==============================] - 1s 1s/step
# 2022-12-15 19:22:01.238359: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
if Model.cfg["CONVERT_TO_TFLITE"]:
    Model.convert_model_to_tflite(model)
# Out:
# 2022-12-15 19:22:10.871936: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2022-12-15 19:22:10.871964: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2022-12-15 19:22:10.872516: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /home/david/SemesterProject/Models/edge_detection/time/TFLITE
# 2022-12-15 19:22:10.914945: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2022-12-15 19:22:10.914978: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /home/david/SemesterProject/Models/edge_detection/time/TFLITE
# 2022-12-15 19:22:11.014429: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2022-12-15 19:22:11.071506: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
# 2022-12-15 19:22:12.846791: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: /home/david/SemesterProject/Models/edge_detection/time/TFLITE
# 2022-12-15 19:22:13.173296: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 2300782 microseconds.
# 2022-12-15 19:22:13.762750: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# === TFLite ModelAnalyzer ===
#
# Your TFLite model has '1' subgraph(s). In the subgraph description below,
# T# represents the Tensor numbers. For example, in Subgraph#0, the DEQUANTIZE op takes
# tensor #1 as input and produces tensor #243 as output.
#
# Subgraph#0 main(T#0) -> [T#686]
#   Op#0 DEQUANTIZE(T#1[]) -> [T#243]
#   Op#1 DEQUANTIZE(T#2[]) -> [T#244]
#   Op#2 DEQUANTIZE(T#3[]) -> [T#245]
#   Op#3 DEQUANTIZE(T#4[]) -> [T#246]
#   Op#4 DEQUANTIZE(T#5[]) -> [T#247]
#   Op#5 DEQUANTIZE(T#6[]) -> [T#248]
#   Op#6 DEQUANTIZE(T#7[]) -> [T#249]
#   Op#7 DEQUANTIZE(T#8[]) -> [T#250]
#   Op#8 DEQUANTIZE(T#9[]) -> [T#251]
#   Op#9 DEQUANTIZE(T#10[]) -> [T#252]
#   Op#10 DEQUANTIZE(T#11[]) -> [T#253]
#   Op#11 DEQUANTIZE(T#12[]) -> [T#254]
#   Op#12 DEQUANTIZE(T#13[]) -> [T#255]
#   Op#13 DEQUANTIZE(T#14[]) -> [T#256]
#   Op#14 DEQUANTIZE(T#15[]) -> [T#257]
#   Op#15 DEQUANTIZE(T#16[]) -> [T#258]
#   Op#16 DEQUANTIZE(T#17[]) -> [T#259]
#   Op#17 DEQUANTIZE(T#18[]) -> [T#260]
#   Op#18 DEQUANTIZE(T#19[]) -> [T#261]
#   Op#19 DEQUANTIZE(T#20[]) -> [T#262]
#   Op#20 DEQUANTIZE(T#21[]) -> [T#263]
#   Op#21 DEQUANTIZE(T#22[]) -> [T#264]
#   Op#22 DEQUANTIZE(T#23[]) -> [T#265]
#   Op#23 DEQUANTIZE(T#24[]) -> [T#266]
#   Op#24 DEQUANTIZE(T#25[]) -> [T#267]
#   Op#25 DEQUANTIZE(T#26[]) -> [T#268]
#   Op#26 DEQUANTIZE(T#27[]) -> [T#269]
#   Op#27 DEQUANTIZE(T#28[]) -> [T#270]
#   Op#28 DEQUANTIZE(T#29[]) -> [T#271]
#   Op#29 DEQUANTIZE(T#30[]) -> [T#272]
#   Op#30 DEQUANTIZE(T#31[]) -> [T#273]
#   Op#31 DEQUANTIZE(T#32[]) -> [T#274]
#   Op#32 DEQUANTIZE(T#33[]) -> [T#275]
#   Op#33 DEQUANTIZE(T#34[]) -> [T#276]
#   Op#34 DEQUANTIZE(T#35[]) -> [T#277]
#   Op#35 DEQUANTIZE(T#36[]) -> [T#278]
#   Op#36 DEQUANTIZE(T#37[]) -> [T#279]
#   Op#37 DEQUANTIZE(T#38[]) -> [T#280]
#   Op#38 DEQUANTIZE(T#39[]) -> [T#281]
#   Op#39 DEQUANTIZE(T#40[]) -> [T#282]
#   Op#40 DEQUANTIZE(T#41[]) -> [T#283]
#   Op#41 DEQUANTIZE(T#42[]) -> [T#284]
#   Op#42 DEQUANTIZE(T#43[]) -> [T#285]
#   Op#43 DEQUANTIZE(T#44[]) -> [T#286]
#   Op#44 DEQUANTIZE(T#45[]) -> [T#287]
#   Op#45 DEQUANTIZE(T#46[]) -> [T#288]
#   Op#46 DEQUANTIZE(T#47[]) -> [T#289]
#   Op#47 DEQUANTIZE(T#48[]) -> [T#290]
#   Op#48 DEQUANTIZE(T#49[]) -> [T#291]
#   Op#49 DEQUANTIZE(T#50[]) -> [T#292]
#   Op#50 DEQUANTIZE(T#51[]) -> [T#293]
#   Op#51 DEQUANTIZE(T#52[]) -> [T#294]
#   Op#52 DEQUANTIZE(T#53[]) -> [T#295]
#   Op#53 DEQUANTIZE(T#54[]) -> [T#296]
#   Op#54 DEQUANTIZE(T#55[]) -> [T#297]
#   Op#55 DEQUANTIZE(T#56[]) -> [T#298]
#   Op#56 DEQUANTIZE(T#57[]) -> [T#299]
#   Op#57 DEQUANTIZE(T#58[]) -> [T#300]
#   Op#58 DEQUANTIZE(T#59[]) -> [T#301]
#   Op#59 DEQUANTIZE(T#60[]) -> [T#302]
#   Op#60 DEQUANTIZE(T#61[]) -> [T#303]
#   Op#61 DEQUANTIZE(T#62[]) -> [T#304]
#   Op#62 DEQUANTIZE(T#63[]) -> [T#305]
#   Op#63 DEQUANTIZE(T#64[]) -> [T#306]
#   Op#64 DEQUANTIZE(T#65[]) -> [T#307]
#   Op#65 DEQUANTIZE(T#66[]) -> [T#308]
#   Op#66 DEQUANTIZE(T#67[]) -> [T#309]
#   Op#67 DEQUANTIZE(T#68[]) -> [T#310]
#   Op#68 DEQUANTIZE(T#69[]) -> [T#311]
#   Op#69 DEQUANTIZE(T#70[]) -> [T#312]
#   Op#70 DEQUANTIZE(T#71[]) -> [T#313]
#   Op#71 DEQUANTIZE(T#72[]) -> [T#314]
#   Op#72 DEQUANTIZE(T#73[]) -> [T#315]
#   Op#73 DEQUANTIZE(T#74[]) -> [T#316]
#   Op#74 DEQUANTIZE(T#75[]) -> [T#317]
#   Op#75 DEQUANTIZE(T#76[]) -> [T#318]
#   Op#76 DEQUANTIZE(T#77[]) -> [T#319]
#   Op#77 DEQUANTIZE(T#78[]) -> [T#320]
#   Op#78 DEQUANTIZE(T#79[]) -> [T#321]
#   Op#79 DEQUANTIZE(T#80[]) -> [T#322]
#   Op#80 DEQUANTIZE(T#81[]) -> [T#323]
#   Op#81 DEQUANTIZE(T#82[]) -> [T#324]
#   Op#82 DEQUANTIZE(T#83[]) -> [T#325]
#   Op#83 DEQUANTIZE(T#84[]) -> [T#326]
#   Op#84 DEQUANTIZE(T#85[]) -> [T#327]
#   Op#85 DEQUANTIZE(T#86[]) -> [T#328]
#   Op#86 DEQUANTIZE(T#87[]) -> [T#329]
#   Op#87 DEQUANTIZE(T#88[]) -> [T#330]
#   Op#88 DEQUANTIZE(T#89[]) -> [T#331]
#   Op#89 DEQUANTIZE(T#90[]) -> [T#332]
#   Op#90 DEQUANTIZE(T#91[]) -> [T#333]
#   Op#91 DEQUANTIZE(T#92[]) -> [T#334]
#   Op#92 DEQUANTIZE(T#93[]) -> [T#335]
#   Op#93 DEQUANTIZE(T#94[]) -> [T#336]
#   Op#94 DEQUANTIZE(T#95[]) -> [T#337]
#   Op#95 DEQUANTIZE(T#96[]) -> [T#338]
#   Op#96 DEQUANTIZE(T#97[]) -> [T#339]
#   Op#97 DEQUANTIZE(T#98[]) -> [T#340]
#   Op#98 DEQUANTIZE(T#99[]) -> [T#341]
#   Op#99 DEQUANTIZE(T#100[]) -> [T#342]
#   Op#100 DEQUANTIZE(T#101[]) -> [T#343]
#   Op#101 DEQUANTIZE(T#102[]) -> [T#344]
#   Op#102 DEQUANTIZE(T#103[]) -> [T#345]
#   Op#103 DEQUANTIZE(T#104[]) -> [T#346]
#   Op#104 DEQUANTIZE(T#105[]) -> [T#347]
#   Op#105 DEQUANTIZE(T#106[]) -> [T#348]
#   Op#106 DEQUANTIZE(T#107[]) -> [T#349]
#   Op#107 DEQUANTIZE(T#108[]) -> [T#350]
#   Op#108 DEQUANTIZE(T#109[]) -> [T#351]
#   Op#109 DEQUANTIZE(T#110[]) -> [T#352]
#   Op#110 DEQUANTIZE(T#111[]) -> [T#353]
#   Op#111 DEQUANTIZE(T#112[]) -> [T#354]
#   Op#112 DEQUANTIZE(T#113[]) -> [T#355]
#   Op#113 DEQUANTIZE(T#114[]) -> [T#356]
#   Op#114 DEQUANTIZE(T#115[]) -> [T#357]
#   Op#115 DEQUANTIZE(T#116[]) -> [T#358]
#   Op#116 DEQUANTIZE(T#117[]) -> [T#359]
#   Op#117 DEQUANTIZE(T#118[]) -> [T#360]
#   Op#118 DEQUANTIZE(T#119[]) -> [T#361]
#   Op#119 DEQUANTIZE(T#120[]) -> [T#362]
#   Op#120 DEQUANTIZE(T#121[]) -> [T#363]
#   Op#121 DEQUANTIZE(T#122[]) -> [T#364]
#   Op#122 DEQUANTIZE(T#123[]) -> [T#365]
#   Op#123 DEQUANTIZE(T#124[]) -> [T#366]
#   Op#124 DEQUANTIZE(T#125[]) -> [T#367]
#   Op#125 DEQUANTIZE(T#126[]) -> [T#368]
#   Op#126 DEQUANTIZE(T#127[]) -> [T#369]
#   Op#127 DEQUANTIZE(T#128[]) -> [T#370]
#   Op#128 DEQUANTIZE(T#129[]) -> [T#371]
#   Op#129 DEQUANTIZE(T#130[]) -> [T#372]
#   Op#130 DEQUANTIZE(T#131[]) -> [T#373]
#   Op#131 DEQUANTIZE(T#132[]) -> [T#374]
#   Op#132 DEQUANTIZE(T#133[]) -> [T#375]
#   Op#133 DEQUANTIZE(T#134[]) -> [T#376]
#   Op#134 DEQUANTIZE(T#135[]) -> [T#377]
#   Op#135 DEQUANTIZE(T#136[]) -> [T#378]
#   Op#136 DEQUANTIZE(T#137[]) -> [T#379]
#   Op#137 DEQUANTIZE(T#138[]) -> [T#380]
#   Op#138 DEQUANTIZE(T#139[]) -> [T#381]
#   Op#139 DEQUANTIZE(T#140[]) -> [T#382]
#   Op#140 DEQUANTIZE(T#141[]) -> [T#383]
#   Op#141 DEQUANTIZE(T#142[]) -> [T#384]
#   Op#142 DEQUANTIZE(T#143[]) -> [T#385]
#   Op#143 DEQUANTIZE(T#144[]) -> [T#386]
#   Op#144 DEQUANTIZE(T#145[]) -> [T#387]
#   Op#145 DEQUANTIZE(T#146[]) -> [T#388]
#   Op#146 DEQUANTIZE(T#147[]) -> [T#389]
#   Op#147 DEQUANTIZE(T#148[]) -> [T#390]
#   Op#148 DEQUANTIZE(T#149[]) -> [T#391]
#   Op#149 DEQUANTIZE(T#150[]) -> [T#392]
#   Op#150 DEQUANTIZE(T#151[]) -> [T#393]
#   Op#151 DEQUANTIZE(T#152[]) -> [T#394]
#   Op#152 DEQUANTIZE(T#153[]) -> [T#395]
#   Op#153 DEQUANTIZE(T#154[]) -> [T#396]
#   Op#154 DEQUANTIZE(T#155[]) -> [T#397]
#   Op#155 DEQUANTIZE(T#156[]) -> [T#398]
#   Op#156 DEQUANTIZE(T#157[]) -> [T#399]
#   Op#157 DEQUANTIZE(T#158[]) -> [T#400]
#   Op#158 DEQUANTIZE(T#159[]) -> [T#401]
#   Op#159 DEQUANTIZE(T#160[]) -> [T#402]
#   Op#160 DEQUANTIZE(T#161[]) -> [T#403]
#   Op#161 DEQUANTIZE(T#162[]) -> [T#404]
#   Op#162 DEQUANTIZE(T#163[]) -> [T#405]
#   Op#163 DEQUANTIZE(T#164[]) -> [T#406]
#   Op#164 DEQUANTIZE(T#165[]) -> [T#407]
#   Op#165 DEQUANTIZE(T#166[]) -> [T#408]
#   Op#166 DEQUANTIZE(T#167[]) -> [T#409]
#   Op#167 DEQUANTIZE(T#168[]) -> [T#410]
#   Op#168 DEQUANTIZE(T#169[]) -> [T#411]
#   Op#169 DEQUANTIZE(T#170[]) -> [T#412]
#   Op#170 DEQUANTIZE(T#171[]) -> [T#413]
#   Op#171 DEQUANTIZE(T#172[]) -> [T#414]
#   Op#172 DEQUANTIZE(T#173[]) -> [T#415]
#   Op#173 DEQUANTIZE(T#174[]) -> [T#416]
#   Op#174 DEQUANTIZE(T#175[]) -> [T#417]
#   Op#175 DEQUANTIZE(T#176[]) -> [T#418]
#   Op#176 DEQUANTIZE(T#177[]) -> [T#419]
#   Op#177 DEQUANTIZE(T#178[]) -> [T#420]
#   Op#178 DEQUANTIZE(T#179[]) -> [T#421]
#   Op#179 DEQUANTIZE(T#180[]) -> [T#422]
#   Op#180 DEQUANTIZE(T#181[]) -> [T#423]
#   Op#181 DEQUANTIZE(T#182[]) -> [T#424]
#   Op#182 DEQUANTIZE(T#183[]) -> [T#425]
#   Op#183 DEQUANTIZE(T#184[]) -> [T#426]
#   Op#184 DEQUANTIZE(T#185[]) -> [T#427]
#   Op#185 DEQUANTIZE(T#186[]) -> [T#428]
#   Op#186 DEQUANTIZE(T#187[]) -> [T#429]
#   Op#187 DEQUANTIZE(T#188[]) -> [T#430]
#   Op#188 DEQUANTIZE(T#189[]) -> [T#431]
#   Op#189 DEQUANTIZE(T#190[]) -> [T#432]
#   Op#190 DEQUANTIZE(T#191[]) -> [T#433]
#   Op#191 DEQUANTIZE(T#192[]) -> [T#434]
#   Op#192 DEQUANTIZE(T#193[]) -> [T#435]
#   Op#193 DEQUANTIZE(T#194[]) -> [T#436]
#   Op#194 DEQUANTIZE(T#195[]) -> [T#437]
#   Op#195 DEQUANTIZE(T#196[]) -> [T#438]
#   Op#196 DEQUANTIZE(T#197[]) -> [T#439]
#   Op#197 DEQUANTIZE(T#198[]) -> [T#440]
#   Op#198 DEQUANTIZE(T#199[]) -> [T#441]
#   Op#199 DEQUANTIZE(T#200[]) -> [T#442]
#   Op#200 DEQUANTIZE(T#201[]) -> [T#443]
#   Op#201 DEQUANTIZE(T#202[]) -> [T#444]
#   Op#202 DEQUANTIZE(T#203[]) -> [T#445]
#   Op#203 DEQUANTIZE(T#204[]) -> [T#446]
#   Op#204 DEQUANTIZE(T#205[]) -> [T#447]
#   Op#205 DEQUANTIZE(T#206[]) -> [T#448]
#   Op#206 DEQUANTIZE(T#207[]) -> [T#449]
#   Op#207 DEQUANTIZE(T#208[]) -> [T#450]
#   Op#208 DEQUANTIZE(T#209[]) -> [T#451]
#   Op#209 DEQUANTIZE(T#210[]) -> [T#452]
#   Op#210 DEQUANTIZE(T#211[]) -> [T#453]
#   Op#211 DEQUANTIZE(T#212[]) -> [T#454]
#   Op#212 DEQUANTIZE(T#213[]) -> [T#455]
#   Op#213 DEQUANTIZE(T#214[]) -> [T#456]
#   Op#214 DEQUANTIZE(T#215[]) -> [T#457]
#   Op#215 DEQUANTIZE(T#216[]) -> [T#458]
#   Op#216 DEQUANTIZE(T#217[]) -> [T#459]
#   Op#217 DEQUANTIZE(T#218[]) -> [T#460]
#   Op#218 DEQUANTIZE(T#219[]) -> [T#461]
#   Op#219 DEQUANTIZE(T#220[]) -> [T#462]
#   Op#220 DEQUANTIZE(T#221[]) -> [T#463]
#   Op#221 DEQUANTIZE(T#222[]) -> [T#464]
#   Op#222 DEQUANTIZE(T#223[]) -> [T#465]
#   Op#223 DEQUANTIZE(T#224[]) -> [T#466]
#   Op#224 DEQUANTIZE(T#225[]) -> [T#467]
#   Op#225 DEQUANTIZE(T#226[]) -> [T#468]
#   Op#226 DEQUANTIZE(T#227[]) -> [T#469]
#   Op#227 DEQUANTIZE(T#228[]) -> [T#470]
#   Op#228 DEQUANTIZE(T#229[]) -> [T#471]
#   Op#229 DEQUANTIZE(T#230[]) -> [T#472]
#   Op#230 DEQUANTIZE(T#231[]) -> [T#473]
#   Op#231 DEQUANTIZE(T#232[]) -> [T#474]
#   Op#232 DEQUANTIZE(T#233[]) -> [T#475]
#   Op#233 DEQUANTIZE(T#234[]) -> [T#476]
#   Op#234 DEQUANTIZE(T#235[]) -> [T#477]
#   Op#235 DEQUANTIZE(T#236[]) -> [T#478]
#   Op#236 DEQUANTIZE(T#237[]) -> [T#479]
#   Op#237 DEQUANTIZE(T#238[]) -> [T#480]
#   Op#238 DEQUANTIZE(T#239[]) -> [T#481]
#   Op#239 DEQUANTIZE(T#240[]) -> [T#482]
#   Op#240 DEQUANTIZE(T#241[]) -> [T#483]
#   Op#241 DEQUANTIZE(T#242[]) -> [T#484]
#   Op#242 CONV_2D(T#0, T#364, T#243) -> [T#485]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#243 CONV_2D(T#485, T#365, T#244) -> [T#486]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#244 CONV_2D(T#485, T#366, T#245) -> [T#487]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#245 ADD(T#486, T#487) -> [T#488]
#   Op#246 CONV_2D(T#485, T#367, T#246) -> [T#489]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#247 ADD(T#488, T#489) -> [T#490]
#   Op#248 CONV_2D(T#485, T#368, T#247) -> [T#491]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#249 ADD(T#490, T#491) -> [T#492]
#   Op#250 CONV_2D(T#485, T#369, T#248) -> [T#493]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#251 ADD(T#492, T#493) -> [T#494]
#   Op#252 CONV_2D(T#494, T#370, T#249) -> [T#495]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#253 CONV_2D(T#495, T#371, T#250) -> [T#496]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#254 CONV_2D(T#495, T#372, T#251) -> [T#497]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#255 CONV_2D(T#495, T#373, T#252) -> [T#498]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#256 CONV_2D(T#495, T#374, T#253) -> [T#499]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#257 ADD(T#498, T#499) -> [T#500]
#   Op#258 CONV_2D(T#495, T#375, T#254) -> [T#501]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#259 ADD(T#500, T#501) -> [T#502]
#   Op#260 ADD(T#502, T#496) -> [T#503]
#   Op#261 ADD(T#503, T#497) -> [T#504]
#   Op#262 CONV_2D(T#504, T#376, T#255) -> [T#505]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#263 CONV_2D(T#505, T#377, T#256) -> [T#506]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#264 CONV_2D(T#505, T#378, T#257) -> [T#507]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#265 ADD(T#506, T#507) -> [T#508]
#   Op#266 CONV_2D(T#505, T#379, T#258) -> [T#509]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#267 ADD(T#508, T#509) -> [T#510]
#   Op#268 CONV_2D(T#505, T#380, T#259) -> [T#511]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#269 ADD(T#510, T#511) -> [T#512]
#   Op#270 CONV_2D(T#505, T#381, T#260) -> [T#513]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#271 ADD(T#512, T#513) -> [T#514]
#   Op#272 CONV_2D(T#514, T#382, T#261) -> [T#515]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#273 CONV_2D(T#515, T#383, T#262) -> [T#516]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#274 CONV_2D(T#515, T#384, T#263) -> [T#517]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#275 ADD(T#516, T#517) -> [T#518]
#   Op#276 CONV_2D(T#515, T#385, T#264) -> [T#519]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#277 ADD(T#518, T#519) -> [T#520]
#   Op#278 CONV_2D(T#515, T#386, T#265) -> [T#521]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#279 ADD(T#520, T#521) -> [T#522]
#   Op#280 CONV_2D(T#515, T#387, T#266) -> [T#523]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#281 ADD(T#522, T#523) -> [T#524]
#   Op#282 CONV_2D(T#524, T#388, T#267) -> [T#525]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#283 CONV_2D(T#525, T#389, T#268) -> [T#526]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#284 CONV_2D(T#525, T#390, T#269) -> [T#527]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#285 ADD(T#526, T#527) -> [T#528]
#   Op#286 CONV_2D(T#525, T#391, T#270) -> [T#529]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#287 ADD(T#528, T#529) -> [T#530]
#   Op#288 CONV_2D(T#525, T#392, T#271) -> [T#531]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#289 ADD(T#530, T#531) -> [T#532]
#   Op#290 CONV_2D(T#525, T#393, T#272) -> [T#533]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#291 ADD(T#532, T#533) -> [T#534]
#   Op#292 CONV_2D(T#534, T#394, T#273) -> [T#535]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#293 CONV_2D(T#535, T#395, T#274) -> [T#536]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#294 CONV_2D(T#535, T#396, T#275) -> [T#537]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#295 ADD(T#536, T#537) -> [T#538]
#   Op#296 CONV_2D(T#535, T#397, T#276) -> [T#539]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#297 ADD(T#538, T#539) -> [T#540]
#   Op#298 CONV_2D(T#535, T#398, T#277) -> [T#541]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#299 ADD(T#540, T#541) -> [T#542]
#   Op#300 CONV_2D(T#535, T#399, T#278) -> [T#543]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#301 ADD(T#542, T#543) -> [T#544]
#   Op#302 CONV_2D(T#544, T#400, T#279) -> [T#545]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#303 CONV_2D(T#545, T#401, T#280) -> [T#546]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#304 CONV_2D(T#545, T#402, T#281) -> [T#547]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#305 ADD(T#546, T#547) -> [T#548]
#   Op#306 CONV_2D(T#545, T#403, T#282) -> [T#549]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#307 ADD(T#548, T#549) -> [T#550]
#   Op#308 CONV_2D(T#545, T#404, T#283) -> [T#551]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#309 ADD(T#550, T#551) -> [T#552]
#   Op#310 CONV_2D(T#545, T#405, T#284) -> [T#553]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#311 ADD(T#552, T#553) -> [T#554]
#   Op#312 CONV_2D(T#554, T#406, T#285) -> [T#555]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#313 CONV_2D(T#555, T#407, T#286) -> [T#556]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#314 CONV_2D(T#555, T#408, T#287) -> [T#557]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#315 ADD(T#556, T#557) -> [T#558]
#   Op#316 CONV_2D(T#555, T#409, T#288) -> [T#559]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#317 ADD(T#558, T#559) -> [T#560]
#   Op#318 CONV_2D(T#555, T#410, T#289) -> [T#561]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#319 ADD(T#560, T#561) -> [T#562]
#   Op#320 CONV_2D(T#555, T#411, T#290) -> [T#563]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#321 ADD(T#562, T#563) -> [T#564]
#   Op#322 CONV_2D(T#564, T#412, T#291) -> [T#565]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#323 CONV_2D(T#565, T#413, T#292) -> [T#566]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#324 CONV_2D(T#565, T#414, T#293) -> [T#567]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#325 ADD(T#566, T#567) -> [T#568]
#   Op#326 CONV_2D(T#565, T#415, T#294) -> [T#569]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#327 ADD(T#568, T#569) -> [T#570]
#   Op#328 CONV_2D(T#565, T#416, T#295) -> [T#571]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#329 ADD(T#570, T#571) -> [T#572]
#   Op#330 CONV_2D(T#565, T#417, T#296) -> [T#573]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#331 ADD(T#572, T#573) -> [T#574]
#   Op#332 CONV_2D(T#574, T#418, T#297) -> [T#575]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#333 CONV_2D(T#575, T#419, T#298) -> [T#576]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#334 CONV_2D(T#575, T#420, T#299) -> [T#577]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#335 ADD(T#576, T#577) -> [T#578]
#   Op#336 CONV_2D(T#575, T#421, T#300) -> [T#579]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#337 ADD(T#578, T#579) -> [T#580]
#   Op#338 CONV_2D(T#575, T#422, T#301) -> [T#581]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#339 ADD(T#580, T#581) -> [T#582]
#   Op#340 CONV_2D(T#575, T#423, T#302) -> [T#583]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#341 ADD(T#582, T#583) -> [T#584]
#   Op#342 CONV_2D(T#584, T#424, T#303) -> [T#585]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#343 CONV_2D(T#585, T#425, T#304) -> [T#586]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#344 CONV_2D(T#585, T#426, T#305) -> [T#587]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#345 ADD(T#586, T#587) -> [T#588]
#   Op#346 CONV_2D(T#585, T#427, T#306) -> [T#589]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#347 ADD(T#588, T#589) -> [T#590]
#   Op#348 CONV_2D(T#585, T#428, T#307) -> [T#591]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#349 ADD(T#590, T#591) -> [T#592]
#   Op#350 CONV_2D(T#585, T#429, T#308) -> [T#593]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#351 ADD(T#592, T#593) -> [T#594]
#   Op#352 CONV_2D(T#594, T#430, T#309) -> [T#595]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#353 CONV_2D(T#595, T#431, T#310) -> [T#596]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#354 CONV_2D(T#595, T#432, T#311) -> [T#597]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#355 ADD(T#596, T#597) -> [T#598]
#   Op#356 CONV_2D(T#595, T#433, T#312) -> [T#599]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#357 ADD(T#598, T#599) -> [T#600]
#   Op#358 CONV_2D(T#595, T#434, T#313) -> [T#601]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#359 ADD(T#600, T#601) -> [T#602]
#   Op#360 CONV_2D(T#595, T#435, T#314) -> [T#603]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#361 ADD(T#602, T#603) -> [T#604]
#   Op#362 CONV_2D(T#604, T#436, T#315) -> [T#605]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#363 CONV_2D(T#605, T#437, T#316) -> [T#606]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#364 CONV_2D(T#605, T#438, T#317) -> [T#607]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#365 ADD(T#606, T#607) -> [T#608]
#   Op#366 CONV_2D(T#605, T#439, T#318) -> [T#609]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#367 ADD(T#608, T#609) -> [T#610]
#   Op#368 CONV_2D(T#605, T#440, T#319) -> [T#611]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#369 ADD(T#610, T#611) -> [T#612]
#   Op#370 CONV_2D(T#605, T#441, T#320) -> [T#613]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#371 ADD(T#612, T#613) -> [T#614]
#   Op#372 CONV_2D(T#614, T#442, T#321) -> [T#615]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#373 CONV_2D(T#615, T#443, T#322) -> [T#616]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#374 CONV_2D(T#615, T#444, T#323) -> [T#617]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#375 ADD(T#616, T#617) -> [T#618]
#   Op#376 CONV_2D(T#615, T#445, T#324) -> [T#619]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#377 ADD(T#618, T#619) -> [T#620]
#   Op#378 CONV_2D(T#615, T#446, T#325) -> [T#621]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#379 ADD(T#620, T#621) -> [T#622]
#   Op#380 CONV_2D(T#615, T#447, T#326) -> [T#623]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#381 ADD(T#622, T#623) -> [T#624]
#   Op#382 CONV_2D(T#624, T#448, T#327) -> [T#625]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#383 CONV_2D(T#625, T#449, T#328) -> [T#626]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#384 CONV_2D(T#625, T#450, T#329) -> [T#627]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#385 ADD(T#626, T#627) -> [T#628]
#   Op#386 CONV_2D(T#625, T#451, T#330) -> [T#629]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#387 ADD(T#628, T#629) -> [T#630]
#   Op#388 CONV_2D(T#625, T#452, T#331) -> [T#631]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#389 ADD(T#630, T#631) -> [T#632]
#   Op#390 CONV_2D(T#625, T#453, T#332) -> [T#633]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#391 ADD(T#632, T#633) -> [T#634]
#   Op#392 CONV_2D(T#634, T#454, T#333) -> [T#635]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#393 CONV_2D(T#635, T#455, T#334) -> [T#636]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#394 CONV_2D(T#635, T#456, T#335) -> [T#637]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#395 ADD(T#636, T#637) -> [T#638]
#   Op#396 CONV_2D(T#635, T#457, T#336) -> [T#639]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#397 ADD(T#638, T#639) -> [T#640]
#   Op#398 CONV_2D(T#635, T#458, T#337) -> [T#641]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#399 ADD(T#640, T#641) -> [T#642]
#   Op#400 CONV_2D(T#635, T#459, T#338) -> [T#643]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#401 ADD(T#642, T#643) -> [T#644]
#   Op#402 CONV_2D(T#644, T#460, T#339) -> [T#645]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#403 CONV_2D(T#645, T#461, T#340) -> [T#646]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#404 CONV_2D(T#645, T#462, T#341) -> [T#647]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#405 CONV_2D(T#645, T#463, T#342) -> [T#648]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#406 CONV_2D(T#645, T#464, T#343) -> [T#649]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#407 ADD(T#648, T#649) -> [T#650]
#   Op#408 CONV_2D(T#645, T#465, T#344) -> [T#651]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#409 ADD(T#650, T#651) -> [T#652]
#   Op#410 ADD(T#652, T#646) -> [T#653]
#   Op#411 ADD(T#653, T#647) -> [T#654]
#   Op#412 CONV_2D(T#654, T#466, T#345) -> [T#655]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#413 CONV_2D(T#655, T#467, T#346) -> [T#656]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#414 CONV_2D(T#655, T#468, T#347) -> [T#657]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#415 ADD(T#656, T#657) -> [T#658]
#   Op#416 CONV_2D(T#655, T#469, T#348) -> [T#659]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#417 ADD(T#658, T#659) -> [T#660]
#   Op#418 CONV_2D(T#655, T#470, T#349) -> [T#661]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#419 ADD(T#660, T#661) -> [T#662]
#   Op#420 CONV_2D(T#655, T#471, T#350) -> [T#663]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#421 ADD(T#662, T#663) -> [T#664]
#   Op#422 CONV_2D(T#664, T#472, T#351) -> [T#665]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#423 CONV_2D(T#665, T#473, T#352) -> [T#666]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#424 CONV_2D(T#665, T#474, T#353) -> [T#667]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#425 ADD(T#666, T#667) -> [T#668]
#   Op#426 CONV_2D(T#665, T#475, T#354) -> [T#669]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#427 ADD(T#668, T#669) -> [T#670]
#   Op#428 CONV_2D(T#665, T#476, T#355) -> [T#671]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#429 ADD(T#670, T#671) -> [T#672]
#   Op#430 CONV_2D(T#665, T#477, T#356) -> [T#673]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#431 ADD(T#672, T#673) -> [T#674]
#   Op#432 CONV_2D(T#674, T#478, T#357) -> [T#675]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#433 CONV_2D(T#675, T#479, T#358) -> [T#676]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#434 CONV_2D(T#675, T#480, T#359) -> [T#677]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#435 ADD(T#676, T#677) -> [T#678]
#   Op#436 CONV_2D(T#675, T#481, T#360) -> [T#679]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#437 ADD(T#678, T#679) -> [T#680]
#   Op#438 CONV_2D(T#675, T#482, T#361) -> [T#681]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#439 ADD(T#680, T#681) -> [T#682]
#   Op#440 CONV_2D(T#675, T#483, T#362) -> [T#683]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#441 ADD(T#682, T#683) -> [T#684]
#   Op#442 CONV_2D(T#684, T#484, T#363) -> [T#685]
# GPU COMPATIBILITY WARNING: Expected 1 or 2 input tensor(s), but node has 3 runtime inputs.
#   Op#443 LOGISTIC(T#685) -> [T#686]
#
# GPU COMPATIBILITY WARNING: Subgraph#0 has GPU delegate compatibility issues at nodes 242, 243, 244, 246, 248, 250, 252, 253, 254, 255, 256, 258, 262, 263, 264, 266, 268, 270, 272, 273, 274, 276, 278, 280, 282, 283, 284, 286, 288, 290, 292, 293, 294, 296, 298, 300, 302, 303, 304, 306, 308, 310, 312, 313, 314, 316, 318, 320, 322, 323, 324, 326, 328, 330, 332, 333, 334, 336, 338, 340, 342, 343, 344, 346, 348, 350, 352, 353, 354, 356, 358, 360, 362, 363, 364, 366, 368, 370, 372, 373, 374, 376, 378, 380, 382, 383, 384, 386, 388, 390, 392, 393, 394, 396, 398, 400, 402, 403, 404, 405, 406, 408, 412, 413, 414, 416, 418, 420, 422, 423, 424, 426, 428, 430, 432, 433, 434, 436, 438, 440, 442 with TFLite runtime version 2.10.0
#
# Tensors of Subgraph#0
#   T#0(serving_default_in_img:0) shape_signature:[-1, 160, 90, 3], type:FLOAT32
#   T#1(model/re_lu/Relu;model/batch_normalization/FusedBatchNormV3;model/conv2d/BiasAdd/ReadVariableOp;model/conv2d/BiasAdd;model/conv2d/Conv2D) shape:[10], type:FLOAT16 RO 20 bytes, data:[]
#   T#2(model/re_lu_1/Relu;model/batch_normalization_1/FusedBatchNormV3;model/conv2d_1/BiasAdd/ReadVariableOp;model/conv2d_1/BiasAdd;model/conv2d_119/Conv2D;model/conv2d_1/Conv2D) shape:[2], type:FLOAT16 RO 4 bytes, data:[]
#   T#3(model/re_lu_2/Relu;model/batch_normalization_2/FusedBatchNormV3;model/conv2d_2/BiasAdd/ReadVariableOp;model/conv2d_2/BiasAdd;model/conv2d_119/Conv2D;model/conv2d_2/Conv2D) shape:[2], type:FLOAT16 RO 4 bytes, data:[]
#   T#4(model/re_lu_3/Relu;model/batch_normalization_3/FusedBatchNormV3;model/conv2d_3/BiasAdd/ReadVariableOp;model/conv2d_3/BiasAdd;model/conv2d_119/Conv2D;model/conv2d_3/Conv2D) shape:[2], type:FLOAT16 RO 4 bytes, data:[]
#   T#5(model/re_lu_4/Relu;model/batch_normalization_4/FusedBatchNormV3;model/conv2d_4/BiasAdd/ReadVariableOp;model/conv2d_4/BiasAdd;model/conv2d_119/Conv2D;model/conv2d_4/Conv2D) shape:[2], type:FLOAT16 RO 4 bytes, data:[]
#   T#6(model/re_lu_5/Relu;model/batch_normalization_5/FusedBatchNormV3;model/conv2d_5/BiasAdd/ReadVariableOp;model/conv2d_5/BiasAdd;model/conv2d_119/Conv2D;model/conv2d_5/Conv2D) shape:[2], type:FLOAT16 RO 4 bytes, data:[]
#   T#7(model/batch_normalization_6/FusedBatchNormV3;model/conv2d_6/BiasAdd/ReadVariableOp;model/conv2d_6/BiasAdd) shape:[1], type:FLOAT16 RO 2 bytes, data:[]
#   T#8(model/re_lu_9/Relu;model/batch_normalization_10/FusedBatchNormV3;model/conv2d_10/BiasAdd/ReadVariableOp;model/conv2d_10/BiasAdd;model/conv2d_119/Conv2D;model/conv2d_10/Conv2D) shape:[2], type:FLOAT16 RO 4 bytes, data:[]
#   T#9(model/re_lu_10/Relu;model/batch_normalization_11/FusedBatchNormV3;model/conv2d_11/BiasAdd/ReadVariableOp;model/conv2d_11/BiasAdd;model/conv2d_119/Conv2D;model/conv2d_11/Conv2D) shape:[2], type:FLOAT16 RO 4 bytes, data:[]
#   T#10(model/re_lu_6/Relu;model/batch_normalization_7/FusedBatchNormV3;model/conv2d_7/BiasAdd/ReadVariableOp;model/conv2d_7/BiasAdd;model/conv2d_119/Conv2D;model/conv2d_7/Conv2D) shape:[2], type:FLOAT16 RO 4 bytes, data:[]
#   T